# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import japanize_matplotlib
np.random.seed(555)
sns.set()

# %% [markdown]
# # 様々なMA(1)を発生させる

# %%
# 平均0, 分散1の正規分布から発生させた乱数100個
arr = np.random.normal(0,1,100)

# %%
plt.plot(arr)

# %%
# 平均0, 標準偏差1の正規分布から発生させた乱数100個
wn = np.random.normal(0,1,100)
# 平均0
mu = 0.0
# θ=0.8
theta_1 = 0.8
map1 = []

for i in range(1,len(wn)):
    map1.append(mu+wn[i]+theta_1*wn[i-1])

# %%
plt.plot(map1)

# %%
# 平均0, 標準偏差1の正規分布から発生させた乱数100個
wn = np.random.normal(0,0.5,100)
# 平均0
mu = 2.0
# θ=0.8
theta_1 = 0.5
map2 = []

for i in range(1,len(wn)):
    map2.append(mu+wn[i]+theta_1*wn[i-1])

# %%
plt.plot(map2)

# %%
# 平均0, 標準偏差1の正規分布から発生させた乱数100個
wn = np.random.normal(0,2,100)
# 平均0
mu = -2.0
# θ=0.8
theta_1 = 0.3
map3 = []

for i in range(1,len(wn)):
    map3.append(mu+wn[i]+theta_1*wn[i-1])

# %%
plt.plot(map3)

# %%
# 平均0, 標準偏差1の正規分布から発生させた乱数100個
wn = np.random.normal(0,1,100)
# 平均0
mu = 0
# θ=0.8
theta_1 = -0.3
map4 = []

for i in range(1,len(wn)):
    map4.append(mu+wn[i]+theta_1*wn[i-1])

# %%
plt.plot(map4)

# %%
# 平均0, 標準偏差1の正規分布から発生させた乱数100個
wn = np.random.normal(0,0.5,100)
# 平均0
mu = 2
# θ=0.8
theta_1 = -0.5
map5 = []

for i in range(1,len(wn)):
    map5.append(mu+wn[i]+theta_1*wn[i-1])

# %%
plt.plot(map5)

# %%
# 平均0, 標準偏差1の正規分布から発生させた乱数100個
wn = np.random.normal(0,2,100)
# 平均0
mu = -2
# θ=0.8
theta_1 = -0.8
map6 = []

for i in range(1,len(wn)):
    map6.append(mu+wn[i]+theta_1*wn[i-1])

# %%
plt.plot(map6)

# %%
# 平均0, 標準偏差1の正規分布から発生させた乱数100個
wn = np.random.normal(0,2,100)
# 平均0
mu = 2
# θ=0.8
theta_1 = -0.5
map7 = []

for i in range(1,len(wn)):
    map7.append(mu+wn[i]+theta_1*wn[i-1])

# %%
plt.plot(map7)
